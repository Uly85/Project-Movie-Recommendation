# %%
#!pip3 install pymongo
import csv 
import json, requests
import pandas as pd
import time
import numpy as np
import psycopg2, os

# %% [markdown]
# ## Populate New York Times Movie Reviews

# %%
from pymongo import MongoClient
client = MongoClient('localhost',27017) ## or MongoClient("localhost:27")
db = client.apan5400

# %%
#Assign New York Times API key
nyt_key = open ('nyt_api_key.txt')
nyt_key = nyt_key.read()
base_url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?query='
api_key = '&api-key='+nyt_key

# %%
#read CSV of IMDB review
imdb = pd.read_csv('movieReviews_IMDB.csv')
detail_title = imdb.movie

titles = list(dict.fromkeys(imdb.movie))

# %%
#create collection movie review new york times
collection = db.moviereview_nyt

# %%
#get new york times review
for title in titles:
    url = base_url+title+api_key
    resp = requests.get(url)
    data = json.loads(resp.text)
    collection.insert_one(data).inserted_id
    time.sleep(3) # to reduce error response

# %%
detail_title = []
detail_review = []
detail_source = []

docs = collection.find()
for doc in docs:
    if("results" in doc and doc["results"] != None):
        for result in doc["results"]:
            detail_title.append(result["display_title"])
            detail_review.append(result["summary_short"])
            detail_source.append("NYT")
    
df = pd.DataFrame({'movie': detail_title, 'user_review': detail_review, 'source': detail_source})
print(df)
# Out:
#                                       movie  \
# 0                     The Dark Knight Rises
# 1                           The Dark Knight
# 2                                 Inception
# 3                                  Parasite
# 4                                     Seven
# ..                                      ...
# 884                             The Wailing
# 885                       Nocturnal Animals
# 886  The Conjuring: The Devil Made Me Do It
# 887                         The Conjuring 2
# 888                           The Conjuring
#
#                                            user_review source
# 0    Christopher Nolan’s “Dark Knight Rises” wraps ...    NYT
# 1    Pitched at the divide between art and industry...    NYT
# 2    In Christopher Nolan’s “Inception” a specialis...    NYT
# 3    In Bong Joon Ho’s new film, a destitute family...    NYT
# 4     Murders based on seven deadly sins. Deadly dull.    NYT
# ..                                                 ...    ...
# 884  Na Hong-jin’s movie about demonic possession i...    NYT
# 885  This thriller, directed by Tom Ford, toggles b...    NYT
# 886  In the third “Conjuring” movie, Ed and Lorrain...    NYT
# 887  James Wan’s sequel to his horror hit concerns ...    NYT
# 888  In James Wan’s horror tale, Lili Taylor and Ro...    NYT
#
# [889 rows x 3 columns]

# %%
df['user_review'].replace('', np.nan, inplace=True)
print(df)
# Out:
#                                movie  \
# 0              The Dark Knight Rises
# 1                    The Dark Knight
# 2                          Inception
# 3                           Parasite
# 4                              Seven
# ..                               ...
# 456                      The Wailing
# 457                Nocturnal Animals
# 458             John Wick: Chapter 2
# 459                   Predestination
# 460  The Hunger Games: Catching Fire
#
#                                            user_review source
# 0    Christopher Nolan’s “Dark Knight Rises” wraps ...    NYT
# 1    Pitched at the divide between art and industry...    NYT
# 2    In Christopher Nolan’s “Inception” a specialis...    NYT
# 3    In Bong Joon Ho’s new film, a destitute family...    NYT
# 4     Murders based on seven deadly sins. Deadly dull.    NYT
# ..                                                 ...    ...
# 456  Na Hong-jin’s movie about demonic possession i...    NYT
# 457  This thriller, directed by Tom Ford, toggles b...    NYT
# 458  This sequel is an altogether more solemn affai...    NYT
# 459  Based on a short story by the science-fiction ...    NYT
# 460  “The Hunger Games: Catching Fire,” the second ...    NYT
#
# [461 rows x 3 columns]

# %%
df.dropna(subset=['user_review'], inplace=True)
print(df)
# Out:
#                                movie  \
# 0              The Dark Knight Rises
# 1                    The Dark Knight
# 2                          Inception
# 3                           Parasite
# 4                              Seven
# ..                               ...
# 456                      The Wailing
# 457                Nocturnal Animals
# 458             John Wick: Chapter 2
# 459                   Predestination
# 460  The Hunger Games: Catching Fire
#
#                                            user_review source
# 0    Christopher Nolan’s “Dark Knight Rises” wraps ...    NYT
# 1    Pitched at the divide between art and industry...    NYT
# 2    In Christopher Nolan’s “Inception” a specialis...    NYT
# 3    In Bong Joon Ho’s new film, a destitute family...    NYT
# 4     Murders based on seven deadly sins. Deadly dull.    NYT
# ..                                                 ...    ...
# 456  Na Hong-jin’s movie about demonic possession i...    NYT
# 457  This thriller, directed by Tom Ford, toggles b...    NYT
# 458  This sequel is an altogether more solemn affai...    NYT
# 459  Based on a short story by the science-fiction ...    NYT
# 460  “The Hunger Games: Catching Fire,” the second ...    NYT
#
# [427 rows x 3 columns]

# %%
# save the dataframe to a csv file.
df.to_csv('movieReviews_NYT.csv', index=False)

# %% [markdown]
# ## Sentiment Analysis (Positive/Negative Reviews)
# Reference: https://hub.packtpub.com/how-to-perform-sentiment-analysis-using-python-tutorial/

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews

# %%
def extract_features(word_list):
    return dict([(word, True) for word in word_list])

# %%
if __name__=='__main__':
    positive_fileids = movie_reviews.fileids('pos')
    negative_fileids = movie_reviews.fileids('neg')

# %%
features_positive = [(extract_features(movie_reviews.words(fileids=[f])),
                      'Positive') for f in positive_fileids]
features_negative = [(extract_features(movie_reviews.words(fileids=[f])),
                      'Negative') for f in negative_fileids]

# %%
# Split the data into train and test (80/20)
threshold_factor = 0.8
threshold_positive = int(threshold_factor * len(features_positive))
threshold_negative = int(threshold_factor * len(features_negative))

# %%
features_train = features_positive[:threshold_positive] + features_negative[:threshold_negative]
features_test = features_positive[threshold_positive:] + features_negative[threshold_negative:]  
print("\nNumber of training datapoints:", len(features_train))
print("Number of test datapoints:", len(features_test))
# Out:
# Number of training datapoints: 1600
# Number of test datapoints: 400

# %%
# Train a Naive Bayes classifier
classifier = NaiveBayesClassifier.train(features_train)
print("\nAccuracy of the classifier:", nltk.classify.util.accuracy(classifier, features_test))
# Out:
# Accuracy of the classifier: 0.735

# %%
sentiment = []

for review in df.user_review:
    probdist = classifier.prob_classify(extract_features(review.split()))
    pred_sentiment = probdist.max().lower()
    sentiment.append(pred_sentiment)

# %%
df['sentiment'] = sentiment
print(df)
# Out:
#                                movie  \
# 0              The Dark Knight Rises
# 1                    The Dark Knight
# 2                          Inception
# 3                           Parasite
# 4                              Seven
# ..                               ...
# 456                      The Wailing
# 457                Nocturnal Animals
# 458             John Wick: Chapter 2
# 459                   Predestination
# 460  The Hunger Games: Catching Fire
#
#                                            user_review source sentiment
# 0    Christopher Nolan’s “Dark Knight Rises” wraps ...    NYT  positive
# 1    Pitched at the divide between art and industry...    NYT  positive
# 2    In Christopher Nolan’s “Inception” a specialis...    NYT  positive
# 3    In Bong Joon Ho’s new film, a destitute family...    NYT  negative
# 4     Murders based on seven deadly sins. Deadly dull.    NYT  positive
# ..                                                 ...    ...       ...
# 456  Na Hong-jin’s movie about demonic possession i...    NYT  negative
# 457  This thriller, directed by Tom Ford, toggles b...    NYT  positive
# 458  This sequel is an altogether more solemn affai...    NYT  negative
# 459  Based on a short story by the science-fiction ...    NYT  positive
# 460  “The Hunger Games: Catching Fire,” the second ...    NYT  positive
#
# [427 rows x 4 columns]

# %% [markdown]
# ## Combine IMDB + NYT Movie Reviews

# %%
sentiment = []
source = []

for review in imdb.user_review:
    probdist = classifier.prob_classify(extract_features(review.split()))
    pred_sentiment = probdist.max().lower()
    sentiment.append(pred_sentiment)
    source.append('IMDB')

imdb['sentiment'] = sentiment
imdb['source'] = source

# %%
df = df.append(imdb, sort = False)
print(df)
# Out:
#                                movie  \
# 0              The Dark Knight Rises
# 1                    The Dark Knight
# 2                          Inception
# 3                           Parasite
# 4                              Seven
# ..                               ...
# 495  The Hunger Games: Catching Fire
# 496           Jo Nesbø's Headhunters
# 497           Jo Nesbø's Headhunters
# 498                    The Conjuring
# 499                    The Conjuring
#
#                                            user_review source sentiment
# 0    Christopher Nolan’s “Dark Knight Rises” wraps ...    NYT  positive
# 1    Pitched at the divide between art and industry...    NYT  positive
# 2    In Christopher Nolan’s “Inception” a specialis...    NYT  positive
# 3    In Bong Joon Ho’s new film, a destitute family...    NYT  negative
# 4     Murders based on seven deadly sins. Deadly dull.    NYT  positive
# ..                                                 ...    ...       ...
# 495  Ever since I first saw it in theaters, Catchin...   IMDB  positive
# 496  The great German word fremdschämen means "seco...   IMDB  negative
# 497  Headhunters is FANTASTIC. If you hate subtitle...   IMDB  positive
# 498  Adequate and decent horror picture in which a ...   IMDB  positive
# 499  I'm an avid horror fan. Lately I've been think...   IMDB  positive
#
# [927 rows x 4 columns]

# %% [markdown]
# ## Adding sentiment scores

# %%
movies = pd.read_csv('negativeSentimentOfMovies.csv')
movies = pd.read_csv('negativeSentimentOfMovies.csv', index_col=0)

# %%
movies
# Out:
#                         movie  \
# index
# 0             The Dark Knight
# 1             The Dark Knight
# 2                   Inception
# 3                   Inception
# 4                    Parasite
# ...                       ...
# 495    Jo Nesbø's Headhunters
# 496             The Conjuring
# 497             The Conjuring
# 498                Disconnect
# 499                Disconnect
#
#                                              user_review sentiment  \
# index
# 0      If someone else acted as Joker, I would give t...  negative
# 1      Totally one of the greatest movie titles ever ...  positive
# 2      The central idea of "Inception" is an interest...  negative
# 3      My 3rd time watching this movie! Yet, it still...  positive
# 4      There are a few suspenseful scenes and a decen...  negative
# ...                                                  ...       ...
# 495    Headhunters is FANTASTIC. If you hate subtitle...  positive
# 496    Adequate and decent horror picture in which a ...  negative
# 497    I'm an avid horror fan. Lately I've been think...  positive
# 498    I found this film, directed by Henry-Alex Rubi...  negative
# 499    I see a lot of movies, and the great majority ...  positive
#
#        negative sentiment
# index
# 0                0.138268
# 1                0.003493
# 2                0.392330
# 3               -1.000000
# 4                0.560443
# ...                   ...
# 495              0.062805
# 496             -1.000000
# 497              0.077141
# 498              0.030692
# 499              0.004877
#
# [500 rows x 4 columns]

# %%
df = pd.merge(df, movies[['movie', 'sentiment', 'negative sentiment']], how='left', on=['movie', 'sentiment'])

# %%
df
# Out:
#                                movie  \
# 0              The Dark Knight Rises
# 1                    The Dark Knight
# 2                          Inception
# 3                           Parasite
# 4                              Seven
# ..                               ...
# 927  The Hunger Games: Catching Fire
# 928           Jo Nesbø's Headhunters
# 929           Jo Nesbø's Headhunters
# 930                    The Conjuring
# 931                    The Conjuring
#
#                                            user_review source sentiment  \
# 0    Christopher Nolan’s “Dark Knight Rises” wraps ...    NYT  positive
# 1    Pitched at the divide between art and industry...    NYT  positive
# 2    In Christopher Nolan’s “Inception” a specialis...    NYT  positive
# 3    In Bong Joon Ho’s new film, a destitute family...    NYT  negative
# 4     Murders based on seven deadly sins. Deadly dull.    NYT  positive
# ..                                                 ...    ...       ...
# 927  Ever since I first saw it in theaters, Catchin...   IMDB  positive
# 928  The great German word fremdschämen means "seco...   IMDB  negative
# 929  Headhunters is FANTASTIC. If you hate subtitle...   IMDB  positive
# 930  Adequate and decent horror picture in which a ...   IMDB  positive
# 931  I'm an avid horror fan. Lately I've been think...   IMDB  positive
#
#      negative sentiment
# 0                   NaN
# 1              0.003493
# 2             -1.000000
# 3              0.560443
# 4                   NaN
# ..                  ...
# 927            0.006867
# 928            0.588086
# 929            0.062805
# 930            0.077141
# 931            0.077141
#
# [932 rows x 5 columns]

# %%
#be careful
#col.remove()

# %% [markdown]
# ## Store to MongoDB

# %%
data_dict = df.to_dict(orient='records')  

col = db.movie_reviews
col.insert_many(data_dict)

# %%
#to erase all data (if needed)
#collection.delete_many({})
print(col.count_documents({}))
# Out:
# 932

# %%
#read CSV of IMDB review
tmdb = pd.read_csv('tmdb_dt.csv')
print(tmdb)
movie_title = tmdb.title
tmdb = tmdb.drop_duplicates(subset = ["title"])
print(tmdb)
# Out:
#                                         genres      id  \
# 0           ['action', 'adventure', 'fantasy']   19995
# 1           ['adventure', 'fantasy', 'action']     285
# 2             ['action', 'adventure', 'crime']  206647
# 3                 ['action', 'crime', 'drama']   49026
# 4    ['action', 'adventure', 'sciencefiction']   49529
# ..                                         ...     ...
# 495           ['adventure', 'comedy', 'drama']    9447
# 496         ['fantasy', 'action', 'adventure']  274854
# 497   ['thriller', 'action', 'sciencefiction']    8870
# 498      ['adventure', 'fantasy', 'animation']    9992
# 499                  ['documentary', 'family']   36970
#
#                                               keywords original_language  \
# 0               ['cultureclash', 'future', 'spacewar']                en
# 1               ['ocean', 'drugabuse', 'exoticisland']                en
# 2               ['spy', 'basedonnovel', 'secretagent']                en
# 3            ['dccomics', 'crimefighter', 'terrorist']                en
# 4                ['basedonnovel', 'mars', 'medallion']                en
# ..                                                 ...               ...
# 495            ['piggybank', 'shortageofmoney', 'pig']                en
# 496                   ['newyork', 'witch', 'uprising']                en
# 497                    ['mars', 'future', 'astronaut']                en
# 498  ['grandfathergrandsonrelationship', 'wretch', ...                en
# 499                           ['ocean', 'sea', 'fish']                en
#
#                       original_title  \
# 0                    The Dark Knight
# 1                    The Dark Knight
# 2                          Inception
# 3                          Inception
# 4                           Parasite
# ..                               ...
# 495  The Hunger Games: Catching Fire
# 496          Jo Nesb√∏'s Headhunters
# 497          Jo Nesb√∏'s Headhunters
# 498                    The Conjuring
# 499                    The Conjuring
#
#                                               overview    status  \
# 0    In the 22nd century, a paraplegic Marine is di...  Released
# 1    Captain Barbossa, long believed to be dead, ha...  Released
# 2    A cryptic message from Bond‚Äôs past sends him...  Released
# 3    Following the death of District Attorney Harve...  Released
# 4    John Carter is a war-weary, former military ca...  Released
# ..                                                 ...       ...
# 495  Babe, fresh from his victory in the sheepherdi...  Released
# 496  The modern world holds many secrets, but by fa...  Released
# 497  Astronauts search for solutions to save a dyin...  Released
# 498  Arthur is a spirited ten-year old whose parent...  Released
# 499  An ecological drama/documentary, filmed throug...  Released
#
#                                title  \
# 0                    The Dark Knight
# 1                    The Dark Knight
# 2                          Inception
# 3                          Inception
# 4                           Parasite
# ..                               ...
# 495  The Hunger Games: Catching Fire
# 496          Jo Nesb√∏'s Headhunters
# 497          Jo Nesb√∏'s Headhunters
# 498                    The Conjuring
# 499                    The Conjuring
#
#                                            user_review  \
# 0    If someone else acted as Joker, I would give t...
# 1    Totally one of the greatest movie titles ever ...
# 2    I will try not to repeat some of what others h...
# 3    My 3rd time watching this movie! Yet, it still...
# 4    After reading all the glowing reviews, especia...
# ..                                                 ...
# 495  Ever since I first saw it in theaters, Catchin...
# 496  The great German word fremdsch√§men means "sec...
# 497  Headhunters is FANTASTIC. If you hate subtitle...
# 498  Adequate and decent horror picture in which a ...
# 499  I'm an avid horror fan. Lately I've been think...
#
#                                                   soup
# 0    cultureclash future spacewar samworthington zo...
# 1    ocean drugabuse exoticisland johnnydepp orland...
# 2    spy basedonnovel secretagent danielcraig chris...
# 3    dccomics crimefighter terrorist christianbale ...
# 4    basedonnovel mars medallion taylorkitsch lynnc...
# ..                                                 ...
# 495  piggybank shortageofmoney pig jamescromwell ma...
# 496  newyork witch uprising vindiesel roseleslie el...
# 497  mars future astronaut valkilmer carrie-annemos...
# 498  grandfathergrandsonrelationship wretch treasur...
# 499  ocean sea fish piercebrosnan jacquesperrin rie...
#
# [500 rows x 10 columns]
#                                         genres      id  \
# 0           ['action', 'adventure', 'fantasy']   19995
# 2             ['action', 'adventure', 'crime']  206647
# 4    ['action', 'adventure', 'sciencefiction']   49529
# 6                      ['animation', 'family']   38757
# 8           ['adventure', 'fantasy', 'family']     767
# ..                                         ...     ...
# 490        ['action', 'sciencefiction', 'war']    5491
# 492              ['drama', 'music', 'romance']   10197
# 494                     ['drama', 'adventure']    9922
# 496         ['fantasy', 'action', 'adventure']  274854
# 498      ['adventure', 'fantasy', 'animation']    9992
#
#                                               keywords original_language  \
# 0               ['cultureclash', 'future', 'spacewar']                en
# 2               ['spy', 'basedonnovel', 'secretagent']                en
# 4                ['basedonnovel', 'mars', 'medallion']                en
# 6                        ['hostage', 'magic', 'horse']                en
# 8                          ['witch', 'magic', 'broom']                en
# ..                                                 ...               ...
# 490   ['basedonnovel', 'post-apocalyptic', 'dystopia']                en
# 492              ['memory', 'sidewalkcafe', 'roomkey']                en
# 494                         ['usa', 'post', 'postman']                en
# 496                   ['newyork', 'witch', 'uprising']                en
# 498  ['grandfathergrandsonrelationship', 'wretch', ...                en
#
#                       original_title  \
# 0                    The Dark Knight
# 2                          Inception
# 4                           Parasite
# 6                              Se7en
# 8           The Silence of the Lambs
# ..                               ...
# 490                         Who Am I
# 492                   Predestination
# 494  The Hunger Games: Catching Fire
# 496          Jo Nesb√∏'s Headhunters
# 498                    The Conjuring
#
#                                               overview    status  \
# 0    In the 22nd century, a paraplegic Marine is di...  Released
# 2    A cryptic message from Bond‚Äôs past sends him...  Released
# 4    John Carter is a war-weary, former military ca...  Released
# 6    When the kingdom's most wanted-and most charmi...  Released
# 8    As Harry begins his sixth year at Hogwarts, he...  Released
# ..                                                 ...       ...
# 490  In the year 3000, man is no match for the Psyc...  Released
# 492  Arrogant, self-centered movie director Guido C...  Released
# 494  In 2013 there are no highways, no I-ways, no d...  Released
# 496  The modern world holds many secrets, but by fa...  Released
# 498  Arthur is a spirited ten-year old whose parent...  Released
#
#                                title  \
# 0                    The Dark Knight
# 2                          Inception
# 4                           Parasite
# 6                              Se7en
# 8           The Silence of the Lambs
# ..                               ...
# 490                         Who Am I
# 492                   Predestination
# 494  The Hunger Games: Catching Fire
# 496          Jo Nesb√∏'s Headhunters
# 498                    The Conjuring
#
#                                            user_review  \
# 0    If someone else acted as Joker, I would give t...
# 2    I will try not to repeat some of what others h...
# 4    After reading all the glowing reviews, especia...
# 6    David Fincher's bleak, relentless, and ultimat...
# 8    The Silence of the Lambs (1991) is a classic p...
# ..                                                 ...
# 490  Desparately trying to be cool. Never believabl...
# 492  Despite his celebrated status as "The Dean of ...
# 494  Before you catch fire this weekend, be sure to...
# 496  The great German word fremdsch√§men means "sec...
# 498  Adequate and decent horror picture in which a ...
#
#                                                   soup
# 0    cultureclash future spacewar samworthington zo...
# 2    spy basedonnovel secretagent danielcraig chris...
# 4    basedonnovel mars medallion taylorkitsch lynnc...
# 6    hostage magic horse zacharylevi mandymoore don...
# 8    witch magic broom danielradcliffe rupertgrint ...
# ..                                                 ...
# 490  basedonnovel post-apocalyptic dystopia johntra...
# 492  memory sidewalkcafe roomkey judidench danielda...
# 494  usa post postman kevincostner willpatton olivi...
# 496  newyork witch uprising vindiesel roseleslie el...
# 498  grandfathergrandsonrelationship wretch treasur...
#
# [249 rows x 10 columns]

# %% [markdown]
# ## Store to MongoDb for Movie Recommendation

# %%
#create collection movie recommendation
collection = db.tmdb

# %%
data_dict_tmdb = tmdb.to_dict(orient='records')  

#col = data_dict_tmdb
#col.insert_many(data_dict_tmdb)
db.tmdb.insert(data_dict_tmdb)
# Out:
# <ipython-input-33-7e12ea87aae7>:5: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   db.tmdb.insert(data_dict_tmdb)
# [ObjectId('610b1ca2711735c4ba85c71c'),
#  ObjectId('610b1ca2711735c4ba85c71d'),
#  ObjectId('610b1ca2711735c4ba85c71e'),
#  ObjectId('610b1ca2711735c4ba85c71f'),
#  ObjectId('610b1ca2711735c4ba85c720'),
#  ObjectId('610b1ca2711735c4ba85c721'),
#  ObjectId('610b1ca2711735c4ba85c722'),
#  ObjectId('610b1ca2711735c4ba85c723'),
#  ObjectId('610b1ca2711735c4ba85c724'),
#  ObjectId('610b1ca2711735c4ba85c725'),
#  ObjectId('610b1ca2711735c4ba85c726'),
#  ObjectId('610b1ca2711735c4ba85c727'),
#  ObjectId('610b1ca2711735c4ba85c728'),
#  ObjectId('610b1ca2711735c4ba85c729'),
#  ObjectId('610b1ca2711735c4ba85c72a'),
#  ObjectId('610b1ca2711735c4ba85c72b'),
#  ObjectId('610b1ca2711735c4ba85c72c'),
#  ObjectId('610b1ca2711735c4ba85c72d'),
#  ObjectId('610b1ca2711735c4ba85c72e'),
#  ObjectId('610b1ca2711735c4ba85c72f'),
#  ObjectId('610b1ca2711735c4ba85c730'),
#  ObjectId('610b1ca2711735c4ba85c731'),
#  ObjectId('610b1ca2711735c4ba85c732'),
#  ObjectId('610b1ca2711735c4ba85c733'),
#  ObjectId('610b1ca2711735c4ba85c734'),
#  ObjectId('610b1ca2711735c4ba85c735'),
#  ObjectId('610b1ca2711735c4ba85c736'),
#  ObjectId('610b1ca2711735c4ba85c737'),
#  ObjectId('610b1ca2711735c4ba85c738'),
#  ObjectId('610b1ca2711735c4ba85c739'),
#  ObjectId('610b1ca2711735c4ba85c73a'),
#  ObjectId('610b1ca2711735c4ba85c73b'),
#  ObjectId('610b1ca2711735c4ba85c73c'),
#  ObjectId('610b1ca2711735c4ba85c73d'),
#  ObjectId('610b1ca2711735c4ba85c73e'),
#  ObjectId('610b1ca2711735c4ba85c73f'),
#  ObjectId('610b1ca2711735c4ba85c740'),
#  ObjectId('610b1ca2711735c4ba85c741'),
#  ObjectId('610b1ca2711735c4ba85c742'),
#  ObjectId('610b1ca2711735c4ba85c743'),
#  ObjectId('610b1ca2711735c4ba85c744'),
#  ObjectId('610b1ca2711735c4ba85c745'),
#  ObjectId('610b1ca2711735c4ba85c746'),
#  ObjectId('610b1ca2711735c4ba85c747'),
#  ObjectId('610b1ca2711735c4ba85c748'),
#  ObjectId('610b1ca2711735c4ba85c749'),
#  ObjectId('610b1ca2711735c4ba85c74a'),
#  ObjectId('610b1ca2711735c4ba85c74b'),
#  ObjectId('610b1ca2711735c4ba85c74c'),
#  ObjectId('610b1ca2711735c4ba85c74d'),
#  ObjectId('610b1ca2711735c4ba85c74e'),
#  ObjectId('610b1ca2711735c4ba85c74f'),
#  ObjectId('610b1ca2711735c4ba85c750'),
#  ObjectId('610b1ca2711735c4ba85c751'),
#  ObjectId('610b1ca2711735c4ba85c752'),
#  ObjectId('610b1ca2711735c4ba85c753'),
#  ObjectId('610b1ca2711735c4ba85c754'),
#  ObjectId('610b1ca2711735c4ba85c755'),
#  ObjectId('610b1ca2711735c4ba85c756'),
#  ObjectId('610b1ca2711735c4ba85c757'),
#  ObjectId('610b1ca2711735c4ba85c758'),
#  ObjectId('610b1ca2711735c4ba85c759'),
#  ObjectId('610b1ca2711735c4ba85c75a'),
#  ObjectId('610b1ca2711735c4ba85c75b'),
#  ObjectId('610b1ca2711735c4ba85c75c'),
#  ObjectId('610b1ca2711735c4ba85c75d'),
#  ObjectId('610b1ca2711735c4ba85c75e'),
#  ObjectId('610b1ca2711735c4ba85c75f'),
#  ObjectId('610b1ca2711735c4ba85c760'),
#  ObjectId('610b1ca2711735c4ba85c761'),
#  ObjectId('610b1ca2711735c4ba85c762'),
#  ObjectId('610b1ca2711735c4ba85c763'),
#  ObjectId('610b1ca2711735c4ba85c764'),
#  ObjectId('610b1ca2711735c4ba85c765'),
#  ObjectId('610b1ca2711735c4ba85c766'),
#  ObjectId('610b1ca2711735c4ba85c767'),
#  ObjectId('610b1ca2711735c4ba85c768'),
#  ObjectId('610b1ca2711735c4ba85c769'),
#  ObjectId('610b1ca2711735c4ba85c76a'),
#  ObjectId('610b1ca2711735c4ba85c76b'),
#  ObjectId('610b1ca2711735c4ba85c76c'),
#  ObjectId('610b1ca2711735c4ba85c76d'),
#  ObjectId('610b1ca2711735c4ba85c76e'),
#  ObjectId('610b1ca2711735c4ba85c76f'),
#  ObjectId('610b1ca2711735c4ba85c770'),
#  ObjectId('610b1ca2711735c4ba85c771'),
#  ObjectId('610b1ca2711735c4ba85c772'),
#  ObjectId('610b1ca2711735c4ba85c773'),
#  ObjectId('610b1ca2711735c4ba85c774'),
#  ObjectId('610b1ca2711735c4ba85c775'),
#  ObjectId('610b1ca2711735c4ba85c776'),
#  ObjectId('610b1ca2711735c4ba85c777'),
#  ObjectId('610b1ca2711735c4ba85c778'),
#  ObjectId('610b1ca2711735c4ba85c779'),
#  ObjectId('610b1ca2711735c4ba85c77a'),
#  ObjectId('610b1ca2711735c4ba85c77b'),
#  ObjectId('610b1ca2711735c4ba85c77c'),
#  ObjectId('610b1ca2711735c4ba85c77d'),
#  ObjectId('610b1ca2711735c4ba85c77e'),
#  ObjectId('610b1ca2711735c4ba85c77f'),
#  ObjectId('610b1ca2711735c4ba85c780'),
#  ObjectId('610b1ca2711735c4ba85c781'),
#  ObjectId('610b1ca2711735c4ba85c782'),
#  ObjectId('610b1ca2711735c4ba85c783'),
#  ObjectId('610b1ca2711735c4ba85c784'),
#  ObjectId('610b1ca2711735c4ba85c785'),
#  ObjectId('610b1ca2711735c4ba85c786'),
#  ObjectId('610b1ca2711735c4ba85c787'),
#  ObjectId('610b1ca2711735c4ba85c788'),
#  ObjectId('610b1ca2711735c4ba85c789'),
#  ObjectId('610b1ca2711735c4ba85c78a'),
#  ObjectId('610b1ca2711735c4ba85c78b'),
#  ObjectId('610b1ca2711735c4ba85c78c'),
#  ObjectId('610b1ca2711735c4ba85c78d'),
#  ObjectId('610b1ca2711735c4ba85c78e'),
#  ObjectId('610b1ca2711735c4ba85c78f'),
#  ObjectId('610b1ca2711735c4ba85c790'),
#  ObjectId('610b1ca2711735c4ba85c791'),
#  ObjectId('610b1ca2711735c4ba85c792'),
#  ObjectId('610b1ca2711735c4ba85c793'),
#  ObjectId('610b1ca2711735c4ba85c794'),
#  ObjectId('610b1ca2711735c4ba85c795'),
#  ObjectId('610b1ca2711735c4ba85c796'),
#  ObjectId('610b1ca2711735c4ba85c797'),
#  ObjectId('610b1ca2711735c4ba85c798'),
#  ObjectId('610b1ca2711735c4ba85c799'),
#  ObjectId('610b1ca2711735c4ba85c79a'),
#  ObjectId('610b1ca2711735c4ba85c79b'),
#  ObjectId('610b1ca2711735c4ba85c79c'),
#  ObjectId('610b1ca2711735c4ba85c79d'),
#  ObjectId('610b1ca2711735c4ba85c79e'),
#  ObjectId('610b1ca2711735c4ba85c79f'),
#  ObjectId('610b1ca2711735c4ba85c7a0'),
#  ObjectId('610b1ca2711735c4ba85c7a1'),
#  ObjectId('610b1ca2711735c4ba85c7a2'),
#  ObjectId('610b1ca2711735c4ba85c7a3'),
#  ObjectId('610b1ca2711735c4ba85c7a4'),
#  ObjectId('610b1ca2711735c4ba85c7a5'),
#  ObjectId('610b1ca2711735c4ba85c7a6'),
#  ObjectId('610b1ca2711735c4ba85c7a7'),
#  ObjectId('610b1ca2711735c4ba85c7a8'),
#  ObjectId('610b1ca2711735c4ba85c7a9'),
#  ObjectId('610b1ca2711735c4ba85c7aa'),
#  ObjectId('610b1ca2711735c4ba85c7ab'),
#  ObjectId('610b1ca2711735c4ba85c7ac'),
#  ObjectId('610b1ca2711735c4ba85c7ad'),
#  ObjectId('610b1ca2711735c4ba85c7ae'),
#  ObjectId('610b1ca2711735c4ba85c7af'),
#  ObjectId('610b1ca2711735c4ba85c7b0'),
#  ObjectId('610b1ca2711735c4ba85c7b1'),
#  ObjectId('610b1ca2711735c4ba85c7b2'),
#  ObjectId('610b1ca2711735c4ba85c7b3'),
#  ObjectId('610b1ca2711735c4ba85c7b4'),
#  ObjectId('610b1ca2711735c4ba85c7b5'),
#  ObjectId('610b1ca2711735c4ba85c7b6'),
#  ObjectId('610b1ca2711735c4ba85c7b7'),
#  ObjectId('610b1ca2711735c4ba85c7b8'),
#  ObjectId('610b1ca2711735c4ba85c7b9'),
#  ObjectId('610b1ca2711735c4ba85c7ba'),
#  ObjectId('610b1ca2711735c4ba85c7bb'),
#  ObjectId('610b1ca2711735c4ba85c7bc'),
#  ObjectId('610b1ca2711735c4ba85c7bd'),
#  ObjectId('610b1ca2711735c4ba85c7be'),
#  ObjectId('610b1ca2711735c4ba85c7bf'),
#  ObjectId('610b1ca2711735c4ba85c7c0'),
#  ObjectId('610b1ca2711735c4ba85c7c1'),
#  ObjectId('610b1ca2711735c4ba85c7c2'),
#  ObjectId('610b1ca2711735c4ba85c7c3'),
#  ObjectId('610b1ca2711735c4ba85c7c4'),
#  ObjectId('610b1ca2711735c4ba85c7c5'),
#  ObjectId('610b1ca2711735c4ba85c7c6'),
#  ObjectId('610b1ca2711735c4ba85c7c7'),
#  ObjectId('610b1ca2711735c4ba85c7c8'),
#  ObjectId('610b1ca2711735c4ba85c7c9'),
#  ObjectId('610b1ca2711735c4ba85c7ca'),
#  ObjectId('610b1ca2711735c4ba85c7cb'),
#  ObjectId('610b1ca2711735c4ba85c7cc'),
#  ObjectId('610b1ca2711735c4ba85c7cd'),
#  ObjectId('610b1ca2711735c4ba85c7ce'),
#  ObjectId('610b1ca2711735c4ba85c7cf'),
#  ObjectId('610b1ca2711735c4ba85c7d0'),
#  ObjectId('610b1ca2711735c4ba85c7d1'),
#  ObjectId('610b1ca2711735c4ba85c7d2'),
#  ObjectId('610b1ca2711735c4ba85c7d3'),
#  ObjectId('610b1ca2711735c4ba85c7d4'),
#  ObjectId('610b1ca2711735c4ba85c7d5'),
#  ObjectId('610b1ca2711735c4ba85c7d6'),
#  ObjectId('610b1ca2711735c4ba85c7d7'),
#  ObjectId('610b1ca2711735c4ba85c7d8'),
#  ObjectId('610b1ca2711735c4ba85c7d9'),
#  ObjectId('610b1ca2711735c4ba85c7da'),
#  ObjectId('610b1ca2711735c4ba85c7db'),
#  ObjectId('610b1ca2711735c4ba85c7dc'),
#  ObjectId('610b1ca2711735c4ba85c7dd'),
#  ObjectId('610b1ca2711735c4ba85c7de'),
#  ObjectId('610b1ca2711735c4ba85c7df'),
#  ObjectId('610b1ca2711735c4ba85c7e0'),
#  ObjectId('610b1ca2711735c4ba85c7e1'),
#  ObjectId('610b1ca2711735c4ba85c7e2'),
#  ObjectId('610b1ca2711735c4ba85c7e3'),
#  ObjectId('610b1ca2711735c4ba85c7e4'),
#  ObjectId('610b1ca2711735c4ba85c7e5'),
#  ObjectId('610b1ca2711735c4ba85c7e6'),
#  ObjectId('610b1ca2711735c4ba85c7e7'),
#  ObjectId('610b1ca2711735c4ba85c7e8'),
#  ObjectId('610b1ca2711735c4ba85c7e9'),
#  ObjectId('610b1ca2711735c4ba85c7ea'),
#  ObjectId('610b1ca2711735c4ba85c7eb'),
#  ObjectId('610b1ca2711735c4ba85c7ec'),
#  ObjectId('610b1ca2711735c4ba85c7ed'),
#  ObjectId('610b1ca2711735c4ba85c7ee'),
#  ObjectId('610b1ca2711735c4ba85c7ef'),
#  ObjectId('610b1ca2711735c4ba85c7f0'),
#  ObjectId('610b1ca2711735c4ba85c7f1'),
#  ObjectId('610b1ca2711735c4ba85c7f2'),
#  ObjectId('610b1ca2711735c4ba85c7f3'),
#  ObjectId('610b1ca2711735c4ba85c7f4'),
#  ObjectId('610b1ca2711735c4ba85c7f5'),
#  ObjectId('610b1ca2711735c4ba85c7f6'),
#  ObjectId('610b1ca2711735c4ba85c7f7'),
#  ObjectId('610b1ca2711735c4ba85c7f8'),
#  ObjectId('610b1ca2711735c4ba85c7f9'),
#  ObjectId('610b1ca2711735c4ba85c7fa'),
#  ObjectId('610b1ca2711735c4ba85c7fb'),
#  ObjectId('610b1ca2711735c4ba85c7fc'),
#  ObjectId('610b1ca2711735c4ba85c7fd'),
#  ObjectId('610b1ca2711735c4ba85c7fe'),
#  ObjectId('610b1ca2711735c4ba85c7ff'),
#  ObjectId('610b1ca2711735c4ba85c800'),
#  ObjectId('610b1ca2711735c4ba85c801'),
#  ObjectId('610b1ca2711735c4ba85c802'),
#  ObjectId('610b1ca2711735c4ba85c803'),
#  ObjectId('610b1ca2711735c4ba85c804'),
#  ObjectId('610b1ca2711735c4ba85c805'),
#  ObjectId('610b1ca2711735c4ba85c806'),
#  ObjectId('610b1ca2711735c4ba85c807'),
#  ObjectId('610b1ca2711735c4ba85c808'),
#  ObjectId('610b1ca2711735c4ba85c809'),
#  ObjectId('610b1ca2711735c4ba85c80a'),
#  ObjectId('610b1ca2711735c4ba85c80b'),
#  ObjectId('610b1ca2711735c4ba85c80c'),
#  ObjectId('610b1ca2711735c4ba85c80d'),
#  ObjectId('610b1ca2711735c4ba85c80e'),
#  ObjectId('610b1ca2711735c4ba85c80f'),
#  ObjectId('610b1ca2711735c4ba85c810'),
#  ObjectId('610b1ca2711735c4ba85c811'),
#  ObjectId('610b1ca2711735c4ba85c812'),
#  ObjectId('610b1ca2711735c4ba85c813'),
#  ObjectId('610b1ca2711735c4ba85c814')]
